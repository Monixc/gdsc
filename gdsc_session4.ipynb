# %%
import tensorflow as tf
from te
8nsorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer

sentences = [
    'Today is a sunny day',
    'Today is a rainy day'
]

tokenizer = Tokenizer(num_words = 100)
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'today': 1, 'is': 2, 'a': 3, 'day': 4, 'sunny': 5, 'rainy': 6}

# %%
sentence = [
    'Today is a sunny day',
    'Today is a rainy day',
    'is It sunny today?'
]
tokenizer = Tokenizer(num_words = 100)
tokenizer.fit_on_texts(sentence)
word_index = tokenizer.word_index

sequence = tokenizer.texts_to_sequences(sentence)
print(sequence)
# Out:
# [[1, 2, 3, 4, 5], [1, 2, 3, 6, 5], [2, 7, 4, 1]]

# %%
test_data = [
    'Today is a snowy day',
    'Will it be rainy tomorrow?'
]

# %%
test_sequences = tokenizer.texts_to_sequences(test_data)
print(word_index)
print(test_sequences)
# Out:
# {'today': 1, 'is': 2, 'a': 3, 'sunny': 4, 'day': 5, 'rainy': 6, 'it': 7}
# [[1, 2, 3, 5], [7, 6]]

# %%
tokenizer = Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index

test_sequences = tokenizer.texts_to_sequences(test_data)
print(word_index)
print(test_sequences)
# Out:
# {'<OOV>': 1, 'today': 2, 'is': 3, 'a': 4, 'day': 5, 'sunny': 6, 'rainy': 7}
# [[2, 3, 4, 1, 5], [1, 1, 1, 7, 1]]

# %%
sentences = [
    'Today is a sunny day',
    'Today is a rainy day',
    'is It sunny today?',
    'I really enjoyed walking in the snow today'
]

# %%
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentence)
print(sequences)
# Out:
# [[2, 3, 4, 6, 5], [2, 3, 4, 7, 5], [3, 8, 6, 2], [9, 10, 11, 12, 13, 14, 15, 2]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded = pad_sequences(sequences)
print(padded)
# Out:
# [[ 0  0  0  2  3  4  6  5]
#  [ 0  0  0  2  3  4  7  5]
#  [ 0  0  0  0  3  8  6  2]
#  [ 9 10 11 12 13 14 15  2]]

# %%
padded = pad_sequences(sequences, padding = 'post')
print(padded)
# Out:
# [[ 2  3  4  6  5  0  0  0]
#  [ 2  3  4  7  5  0  0  0]
#  [ 3  8  6  2  0  0  0  0]
#  [ 9 10 11 12 13 14 15  2]]

# %%
padded = pad_sequences(sequences, padding = 'post', maxlen = 6)
print(padded)
# Out:
# [[ 2  3  4  6  5  0]
#  [ 2  3  4  7  5  0]
#  [ 3  8  6  2  0  0]
#  [11 12 13 14 15  2]]

# %%
padded = pad_sequences(sequences, padding = 'post', maxlen= 6, truncating = 'post')
print(padded)
# Out:
# [[ 2  3  4  6  5  0]
#  [ 2  3  4  7  5  0]
#  [ 3  8  6  2  0  0]
#  [ 9 10 11 12 13 14]]

# %%
#idbm 데이터

import tensorflow_datasets as tfds

imdb_sentences = []
train_data = tfds.as_numpy(tfds.load('imdb_reviews', split = 'train'))

for item in train_data:
  imdb_sentences.append(str(item['text']))
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incomplete4QE14D/imdb_reviews-train.tfrecord…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incomplete4QE14D/imdb_reviews-test.tfrecord*…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incomplete4QE14D/imdb_reviews-unsupervised.t…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words = 5000)
tokenizer.fit_on_texts(imdb_sentences)
sequences = tokenizer.texts_to_sequences(imdb_sentences)

# %%
print(tokenizer.word_index)
# Out:
# {'the': 1, 'and': 2, 'a': 3, 'of': 4, 'to': 5, 'is': 6, 'br': 7, 'in': 8, 'it': 9, 'i': 10, 'this': 11, 'that': 12, 'was': 13, 'as': 14, 'for': 15, 'with': 16, 'movie': 17, 'but': 18, 'film': 19, "'s": 20, 'on': 21, 'you': 22, 'not': 23, 'are': 24, 'his': 25, 'he': 26, 'have': 27, 'be': 28, 'one': 29, 'all': 30, 'at': 31, 'by': 32, 'they': 33, 'an': 34, 'who': 35, 'so': 36, 'from': 37, 'like': 38, 'her': 39, "'t": 40, 'or': 41, 'just': 42, 'there': 43, 'about': 44, 'out': 45, "'": 46, 'has': 47, 'if': 48, 'some': 49, 'what': 50, 'good': 51,
# %%
from bs4 import BeautifulSoup
import string

stopwords = ["a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at",
             "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do",
             "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having",
             "he", "hed", "hes", "her", "here", "heres", "hers", "herself", "him", "himself", "his", "how",
             "hows", "i", "id", "ill", "im", "ive", "if", "in", "into", "is", "it", "its", "itself",
             "lets", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought",
             "our", "ours", "ourselves", "out", "over", "own", "same", "she", "shed", "shell", "shes", "should",
             "so", "some", "such", "than", "that", "thats", "the", "their", "theirs", "them", "themselves", "then",
             "there", "theres", "these", "they", "theyd", "theyll", "theyre", "theyve", "this", "those", "through",
             "to", "too", "under", "until", "up", "very", "was", "we", "wed", "well", "were", "weve", "were",
             "what", "whats", "when", "whens", "where", "wheres", "which", "while", "who", "whos", "whom", "why",
             "whys", "with", "would", "you", "youd", "youll", "youre", "youve", "your", "yours", "yourself",
             "yourselves"]

# %%
table = str.maketrans('', '', string.punctuation)

imdb_sentences = []
train_data = tfds.as_numpy(tfds.load('imdb_reviews', split = 'train'))
for item in train_data:
  sentence = str(item['text'].decode('UTF-8').lower())
  sentece = sentence.replace(",", " , ")
  sentence = sentence.replace(".", " . ")
  sentence = sentence.replace("-", " - ")
  sentence = sentence.replace("/", " / ")
  soup = BeautifulSoup(sentence)
  sentece = soup.get_text()
  words = sentence.split()
  filtered_sentence = ""
  for word in words:
    word = word.translate(table)
    if word not in stopwords:
      filtered_sentence = filtered_sentence + word + " "
  imdb_sentences.append(filtered_sentence)

tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words = 25000)
tokenizer.fit_on_texts(imdb_sentences)
# Out:
# <ipython-input-61-faf7e07602b1>:11: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(sentence)

# %%
print(tokenizer.word_index)
# Out:
# {'br': 1, 'movie': 2, 'film': 3, 'not': 4, 'one': 5, 'like': 6, 'just': 7, 'good': 8, 'no': 9, 'time': 10, 'even': 11, 'story': 12, 'really': 13, 'see': 14, 'can': 15, 'much': 16, 'get': 17, 'bad': 18, 'will': 19, 'also': 20, 'people': 21, 'first': 22, 'great': 23, 'dont': 24, 'made': 25, 'movies': 26, 'make': 27, 'way': 28, 'films': 29, 'characters': 30, 'think': 31, 'watch': 32, 'two': 33, 'character': 34, 'many': 35, 'seen': 36, 'plot': 37, 'life': 38, 'never': 39, 'acting': 40, 'little': 41, 'love': 42, 'best': 43, 'show': 44, 'know': 45, 'off': 46, 'ever': 47, 'better': 48, 'end': 49, 'still': 50, 'man': 51, 'say': 52, 'scene': 53, 'scenes': 54, 'go': 55, 'something': 56, 'back': 57, 'real': 58, 'watching': 59, 'years': 60, 'doesnt': 61, 'now': 62, 'actors': 63, 'though': 64, 'old': 65, 'thing': 66, 'didnt': 67, 'work': 68, 'another': 69, 'new': 70, 'nothing': 71, 'funny': 72, 'actually': 73, 'makes': 74, '10': 75, 'director': 76, 'look': 77, 'find': 78, 'going': 79, 'part': 80, 'every': 81, 'lot': 82, 'cast': 83, 'us': 84, 'cant': 85, 'quite': 86, 'things': 87, 'want': 88, 'world': 89, 'pretty': 90, 'young': 91, 'seems': 92, 'around': 93, 'got': 94, 'horror': 95, 'fact': 96, 'however': 97, 'take': 98, 'big': 99, 'enough': 100, 'long': 101, 'thought': 102, 'series': 103, 'give': 104, 'may': 105, 'original': 106, 'action': 107, 'right': 108, 'without': 109, 'always': 110, 'times': 111, 'gets': 112, 'comedy': 113, 'point': 114, 'must': 115, 'isnt': 116, 'come': 117, 'role': 118, 'saw': 119, 'almost': 120, 'interesting': 121, 'least': 122, 'family': 123, 'done': 124, 'whole': 125, 'bit': 126, 'music': 127, 'script': 128, 'far': 129, 'making': 130, 'guy': 131, 'feel': 132, 'anything': 133, 'minutes': 134, 'last': 135, 'since': 136, 'might': 137, 'performance': 138, 'probably': 139, '2': 140, 'kind': 141, 'away': 142, 'yet': 143, 'rather': 144, 'worst': 145, 'tv': 146, 'girl': 147, 'day': 148, 'sure': 149, 'fun': 150, 'hard': 151, 'woman': 152, 'found': 153, 'played': 154, 'anyone': 155, 'although': 156, 'believe': 157, 'especially': 158, 'course': 159, 'comes': 160, 'screen': 161, 'looking': 162, 'trying': 163, 'set': 164, 'goes': 165, 'shows': 166, 'looks': 167, 'place': 168, 'different': 169, 'put': 170, 'book': 171, 'ending': 172, 'money': 173, 'wasnt': 174, 'maybe': 175, 'true': 176, 'sense': 177, 'reason': 178, 'everything': 179, 'actor': 180, 'dvd': 181, 'worth': 182, 'three': 183, 'year': 184, 'job': 185, 'main': 186, 'together': 187, 'watched': 188, 'someone': 189, 'play': 190, 'plays': 191, 'american': 192, 'effects': 193, 'takes': 194, 'later': 195, 'said': 196, 'instead': 197, 'seem': 198, 'beautiful': 199, 'house': 200, 'high': 201, 'john': 202, 'night': 203, 'version': 204, 'audience': 205, 'everyone': 206, 'left': 207, 'special': 208, 'seeing': 209, '1': 210, 'half': 211, 'excellent': 212, 'star': 213, 'wife': 214, 'shot': 215, 'war': 216, 'idea': 217, 'black': 218, 'nice': 219, 'less': 220, 'mind': 221, 'simply': 222, 'read': 223, 'second': 224, 'father': 225, 'else': 226, 'kids': 227, 'fan': 228, 'help': 229, 'death': 230, 'poor': 231, 'completely': 232, 'used': 233, 'home': 234, 'dead': 235, 'either': 236, 'short': 237, 'men': 238, 'line': 239, 'friends': 240, '3': 241, 'given': 242, 'top': 243, 'budget': 244, 'try': 245, 'classic': 246, 'performances': 247, 'wrong': 248, 'hollywood': 249, 'need': 250, 'enjoy': 251, 'rest': 252, 'use': 253, 'boring': 254, 'low': 255, 'production': 256, 'full': 257, 'camera': 258, 'along': 259, 'truly': 260, 'women': 261, 'video': 262, 'tell': 263, 'awful': 264, 'next': 265, 'couple': 266, 'start': 267, 'stars': 268, 'remember': 269, 'stupid': 270, 'perhaps': 271, 'sex': 272, 'mean': 273, 'came': 274, 'recommend': 275, 'others': 276, 'let': 277, 'moments': 278, 'wonderful': 279, 'understand': 280, 'face': 281, 'small': 282, 'episode': 283, 'school': 284, 'playing': 285, 'terrible': 286, 'getting': 287, 'written': 288, 'keep': 289, 'often': 290, 'early': 291, 'name': 292, 'perf ...

# %%
sentences = [
    'Today is a sunny day',
    'Today is a rainy day',
    'Is it sunny today?'
]
sequences = tokenizer.texts_to_sequences(sentences)
print(sequences)
# Out:
# [[517, 5166, 148], [517, 6486, 148], [5166, 517]]

# %%
reverse_word_index = dict(
    [(value, key) for (key, value) in tokenizer.word_index.items()]
)

decoded_review = ' '.join([reverse_word_index.get(i, '?') for i in sequences[0]])
print(decoded_review)
# Out:
# today sunny day
